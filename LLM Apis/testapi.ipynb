# %%
from openai import OpenAI
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# %pip install --upgrade openai

# %%
client=OpenAI(api_key=os.getenv("GEMINI_API_KEY"),
              base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
response=client.chat.completions.create(
    model="gemini-3.6-flash",
    messages=[
        {"role":"system","content":"You are a helpful assistant."},
         {"role":"assistant","content":"hey how may i help you?"},
        {"role":"user","content":"explain what is machine learning in short"},
       
    ]
)
print(response.choices[0].message.content)
# Out:
# **Machine Learning (ML)** is a branch of artificial intelligence (AI) where computers learn from data to make decisions or predictions, without being explicitly programmed for every rule.
#
# Instead of a human writing code for every single scenario, you feed the system large amounts of data, and it learns to spot patterns and improve on its own.
#
# **Simple Example:** Instead of writing code to describe what a cat looks like, you show the computer thousands of cat photos. It learns the patterns itself and can then recognize cats in new photos it has never seen before.
